# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.random.random(50)
plt.hist(data, bins=30, color='purple', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Ages in number')
plt.ylabel('Population')
plt.show()
